# %%
import pandas as pd

# Series - column of data frame
values = [1, 2, 3, 4, 5]
s = pd.Series(values, index=['a', 'b', 'c', 'd', 'e'])

s

s.loc['a'] # access specific index
    
# Data Frame - collection of series

df = pd.DataFrame({
    'name':['Mike', 'Bob', 'Alice'],
    'age': [20, 34, 23],
    'job': ['Student', 'Programmer', 'Clerk']
})

df = df.set_index('name')

df 

df1 = pd.DataFrame({
    'a': [1, 2, 3]
}, index = [0, 1, 2])

df2 = pd.DataFrame({
    'a': [10, 20, 30]
}, index = [1, 2, 0])

df1 * df2
# Out:
#     a
# 0  30
# 1  20
# 2  60
